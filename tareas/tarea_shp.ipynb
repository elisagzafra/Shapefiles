# %%
# !pip install geopandas
# !pip install geopy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geopandas
#   Downloading geopandas-0.13.0-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.1 MB/s eta 0:00:00
# Collecting fiona>=1.8.19 (from geopandas)
#   Downloading Fiona-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 38.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Collecting pyproj>=3.0.1 (from geopandas)
#   Downloading pyproj-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2022.12.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Collecting click-plugins>=1.0 (from fiona>=1.8.19->geopandas)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.19->geopandas)
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting munch>=2.3.2 (from fiona>=1.8.19->geopandas)
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.22.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from munch>=2.3.2->fiona>=1.8.19->geopandas) (1.16.0)
# Installing collected packages: pyproj, munch, cligj, click-plugins, fiona, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.9.3 geopandas-0.13.0 munch-2.5.0 pyproj-3.5.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (2.3.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy) (2.0)

# %%
# !pip install mapclassify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mapclassify
#   Downloading mapclassify-2.5.0-py3-none-any.whl (39 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.10.1)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.5.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from mapclassify) (3.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->mapclassify) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->mapclassify) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->mapclassify) (1.16.0)
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.5.0

# %%
#Estas son las librerias que vas a usar
import geopandas as gpd
import matplotlib.pyplot as plt
from mapclassify import classify
import pandas as pd
import numpy as np
import folium
import geopy

# %% [markdown]
# 1. Crea un mapa para visualizar el archivo:
# https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_admin_1_states_provinces_shp.geojson

# %%
# tu codigo aqui
url = "https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_admin_1_states_provinces_shp.geojson"
data = gpd.read_file(url)
data.plot()
# Out:
# <Axes: >

# %% [markdown]
# 2. Obtener toda la información sobre el dataframe.

# %%
# tu codigo aqui
# no entendí que había que hacer lol
print(data.info())
# Out:
#     scalerank adm1_code  diss_me adm1_cod_1 iso_3166_2  \
# 0           2  USA-3514     3514   USA-3514      US-MN
# 1           2  USA-3515     3515   USA-3515      US-MT
# 2           2  USA-3516     3516   USA-3516      US-ND
# 3           2  USA-3517     3517   USA-3517      US-HI
# 4           2  USA-3518     3518   USA-3518      US-ID
# 5           2  USA-3519     3519   USA-3519      US-WA
# 6           2  USA-3520     3520   USA-3520      US-AZ
# 7           2  USA-3521     3521   USA-3521      US-CA
# 8           2  USA-3522     3522   USA-3522      US-CO
# 9           2  USA-3523     3523   USA-3523      US-NV
# 10          2  USA-3524     3524   USA-3524      US-NM
# 11          2  USA-3525     3525   USA-3525      US-OR
# 12          2  USA-3526     3526   USA-3526      US-UT
# 13          2  USA-3527     3527   USA-3527      US-WY
# 14          2  USA-3528     3528   USA-3528      US-AR
# 15          2  USA-3529     3529   USA-3529      US-IA
# 16          2  USA-3530     3530   USA-3530      US-KS
# 17          2  USA-3531     3531   USA-3531      US-MO
# 18          2  USA-3532     3532   USA-3532      US-NE
# 19          2  USA-3533     3533   USA-3533      US-OK
# 20          2  USA-3534     3534   USA-3534      US-SD
# 21          2  USA-3535     3535   USA-3535      US-LA
# 22          2  USA-3536     3536   USA-3536      US-TX
# 23          2  USA-3537     3537   USA-3537      US-CT
# 24          2  USA-3513     3513   USA-3513      US-MA
# 25          2  USA-3538     3538   USA-3538      US-NH
# 26          2  USA-3539     3539   USA-3539      US-RI
# 27          2  USA-3540     3540   USA-3540      US-VT
# 28          2  USA-3541     3541   USA-3541      US-AL
# 29          2  USA-3542     3542   USA-3542      US-FL
# 30          2  USA-3543     3543   USA-3543      US-GA
# 31          2  USA-3544     3544   USA-3544      US-MS
# 32          2  USA-3545     3545   USA-3545      US-SC
# 33          2  USA-3546     3546   USA-3546      US-IL
# 34          2  USA-3547     3547   USA-3547      US-IN
# 35          2  USA-3548     3548   USA-3548      US-KY
# 36          2  USA-3549     3549   USA-3549      US-NC
# 37          2  USA-3550     3550   USA-3550      US-OH
# 38          2  USA-3551     3551   USA-3551      US-TN
# 39          2  USA-3552     3552   USA-3552      US-VA
# 40          2  USA-3553     3553   USA-3553      US-WI
# 41          2  USA-3554     3554   USA-3554      US-WV
# 42          2  USA-3555     3555   USA-3555      US-DE
# 43          2  USA-3556     3556   USA-3556      US-DC
# 44          2  USA-3557     3557   USA-3557      US-MD
# 45          2  USA-3558     3558   USA-3558      US-NJ
# 46          2  USA-3559     3559   USA-3559      US-NY
# 47          2  USA-3560     3560   USA-3560      US-PA
# 48          2  USA-3561     3561   USA-3561      US-ME
# 49          2  USA-3562     3562   USA-3562      US-MI
# 50          2  USA-3563     3563   USA-3563      US-AK
#
#                                             wikipedia sr_sov_a3 sr_adm0_a3  \
# 0              http://en.wikipedia.org/wiki/Minnesota       US1        USA
# 1                http://en.wikipedia.org/wiki/Montana       US1        USA
# 2           http://en.wikipedia.org/wiki/North_Dakota       US1        USA
# 3                 http://en.wikipedia.org/wiki/Hawaii       US1        USA
# 4                  http://en.wikipedia.org/wiki/Idaho       US1        USA
# 5     http://en.wikipedia.org/wiki/Washington_(state)       US1        USA
# 6                http://en.wikipedia.org/wiki/Arizona       US1        USA
# 7             http://en.wikipedia.org/wiki/California       US1        USA
# 8               http://en.wikipedia.org/wiki/Colorado       US1        USA
# 9                 http://en.wikipedia.org/wiki/Nevada       US1        USA
# 10            http://en.wikipedia.org/wiki/New_Mexico       US1        USA
# 11                http://en.wikipedia.org/wiki/Oregon       US1        USA
# 12                  http://en.wikipedia.org/wiki/Utah       US1        USA
# 13               http://en.wikipedia.org/wiki/Wyoming       US1        USA
# 14              http://en.wikipedia.org/wiki/Arkansas       US1        USA
# 15                  http://en.wikipedia.org/wiki/Iowa       US1        USA
# 16                http://en.wikipedia.org/wiki/Kansas       US1        USA
# 17              http://en.wikipedia.org/wiki/Missouri       US1        USA
# 18              http://en.wikipedia.org/wiki/Nebraska       US1        USA
# 19              http://en.wikipedia.org/wiki/Oklahoma       US1        USA
# 20          http://en.wikipedia.org/wiki/South_Dakota       US1        USA
# 21             http://en.wikipedia.org/wiki/Louisiana       US1        USA
# 22                 http://en.wikipedia.org/wiki/Texas       US1        USA
# 23           http://en.wikipedia.org/wiki/Connecticut       US1        USA
# 24         http://en.wikipedia.org/wiki/Massachusetts       US1        USA
# 25         http://en.wikipedia.org/wiki/New_Hampshire       US1        USA
# 26          http://en.wikipedia.org/wiki/Rhode_Island       US1        USA
# 27               http://en.wikipedia.org/wiki/Vermont       US1        USA
# 28               http://en.wikipedia.org/wiki/Alabama       US1        USA
# 29               http://en.wikipedia.org/wiki/Florida       US1        USA
# 30  http://en.wikipedia.org/wiki/Georgia_(U.S._state)       US1        USA
# 31           http://en.wikipedia.org/wiki/Mississippi       US1        USA
# 32        http://en.wikipedia.org/wiki/South_Carolina       US1        USA
# 33              http://en.wikipedia.org/wiki/Illinois       US1        USA
# 34               http://en.wikipedia.org/wiki/Indiana       US1        USA
# 35              http://en.wikipedia.org/wiki/Kentucky       US1        USA
# 36        http://en.wikipedia.org/wiki/North_Carolina       US1        USA
# 37                  http://en.wikipedia.org/wiki/Ohio       US1        USA
# 38             http://en.wikipedia.org/wiki/Tennessee       US1        USA
# 39              http://en.wikipedia.org/wiki/Virginia       US1        USA
# 40             http://en.wikipedia.org/wiki/Wisconsin       US1        USA
# 41         http://en.wikipedia.org/wiki/West_Virginia       US1        USA
# 42              http://en.wikipedia.org/wiki/Delaware       US1        USA
# 43      http://en.wikipedia.org/wiki/Washington,_D.C.       US1        USA
# 44              http://en.wikipedia.org/wiki/Maryland       US1        USA
# 45            http://en.wikipedia.org/wiki/New_Jersey       US1        USA
# 46              http://en.wikipedia.org/wiki/New_York       US1        USA
# 47          http://en.wikipedia.org/wiki/Pennsylvania       US1        USA
# 48                 http://en.wikipedia.org/wiki/Maine       US1        USA
# 49              http://en.wikipedia.org/wiki/Michigan       US1        USA
# 50                http://en.wikipedia.org/wiki/Alaska       US1        USA
#
#    iso_a2  adm0_sr  ...  area_sqkm sameascity labelrank          featurec_1  \
# 0      US        1  ...          0        -99         0  Admin-1 scale rank
# 1      US        1  ...          0        -99         0  Admin-1 scale rank
# 2      US        1  ...          0        -99         0  Admin-1 scale rank
# 3      US        8  ...          0        -99         0  Admin-1 scale rank
# 4      US        1  ...          0        -99         0  Admin-1 scale rank
# 5      US        6  ...          0        -99         0  Admin-1 scale rank
# 6      US        1  ...          0        -99         0  Admin-1 scale rank
# 7      US        8  ...          0        -99         0  Admin-1 scale rank
# 8      US        1  ...          0        -99         0  Admin-1 scale rank
# 9      US        1  ...          0        -99         0  Admin-1 scale rank
# 10     US        1  ...          0        -99         0  Admin-1 scale rank
# 11     US        6  ...          0        -99         0  Admin-1 scale rank
# 12     US        1  ...          0        -99         0  Admin-1 scale rank
# 13     US        1  ...          0        -99         0  Admin-1 scale rank
# 14     US        1  ...          0        -99         0  Admin-1 scale rank
# 15     US        1  ...          0        -99         0  Admin-1 scale rank
# 16     US        1  ...          0        -99         0  Admin-1 scale rank
# 17     US        1  ...          0        -99         0  Admin-1 scale rank
# 18     US        1  ...          0        -99         0  Admin-1 scale rank
# 19     US        1  ...          0        -99         0  Admin-1 scale rank
# 20     US        1  ...          0        -99         0  Admin-1 scale rank
# 21     US        5  ...          0        -99         0  Admin-1 scale rank
# 22     US        4  ...          0        -99         0  Admin-1 scale rank
# 23     US        1  ...          0        -99         0  Admin-1 scale rank
# 24     US        6  ...          0        -99         0  Admin-1 scale rank
# 25     US        1  ...          0        -99         0  Admin-1 scale rank
# 26     US        6  ...          0        -99         0  Admin-1 scale rank
# 27     US        1  ...          0        -99         0  Admin-1 scale rank
# 28     US        5  ...          0        -99         0  Admin-1 scale rank
# 29     US        5  ...          0        -99         0  Admin-1 scale rank
# 30     US        6  ...          0        -99         0  Admin-1 scale rank
# 31     US        5  ...          0        -99         0  Admin-1 scale rank
# 32     US        1  ...          0        -99         0  Admin-1 scale rank
# 33     US        1  ...          0        -99         0  Admin-1 scale rank
# 34     US        1  ...          0        -99         0  Admin-1 scale rank
# 35     US        1  ...          0        -99         0  Admin-1 scale rank
# 36     US        5  ...          0        -99         0  Admin-1 scale rank
# 37     US        1  ...          0        -99         0  Admin-1 scale rank
# 38     US        1  ...          0        -99         0  Admin-1 scale rank
# 39     US        6  ...          0        -99         0  Admin-1 scale rank
# 40     US        1  ...          0        -99         0  Admin-1 scale rank
# 41     US        1  ...          0        -99         0  Admin-1 scale rank
# 42     US        1  ...          0        -99         0  Admin-1 scale rank
# 43     US        1  ...          0          9         9  Admin-1 scale rank
# 44     US        1  ...          0        -99         0  Admin-1 scale rank
# 45     US        5  ...          0        -99         0  Admin-1 scale rank
# 46     US        3  ...          0        -99         0  Admin-1 scale rank
# 47     US        1  ...          0        -99         0  Admin-1 scale rank
# 48     US        6  ...          0        -99         0  Admin-1 scale rank
# 49     US        1  ...          0        -99         0  Admin-1 scale rank
# 50     US        6  ...          0        -99         0  Admin-1 scale rank
#
#                        admin name_len mapcolor9 mapcolor13  \
# 0   United States of America        9         1          1
# 1   United States of America        7         1          1
# 2   United States of America       12         1          1
# 3   United States of America        6         1          1
# 4   United States of America        5         1          1
# 5   United States of America       10         1          1
# 6   United States of America        7         1          1
# 7   United States of America       10         1          1
# 8   United States of America        8         1          1
# 9   United States of America        6         1          1
# 10  United States of America       10         1          1
# 11  United States of America        6         1          1
# 12  United States of America        4         1          1
# 13  United States of America        7         1          1
# 14  United States of America        8         1          1
# 15  United States of America        4         1          1
# 16  United States of America        6         1          1
# 17  United States of America        8         1          1
# 18  United States of America        8         1          1
# 19  United States of America        8         1          1
# 20  United States of America       12         1          1
# 21  United States of America        9         1          1
# 22  United States of America        5         1          1
# 23  United States of America       11         1          1
# 24  United States of America       13         1          1
# 25  United States of America       13         1          1
# 26  United States of America       12         1          1
# 27  United States of America        7         1          1
# 28  United States of America        7         1          1
# 29  United States of America        7         1          1
# 30  United States of America        7         1          1
# 31  United States of America       11         1          1
# 32  United States of America       14         1          1
# 33  United States of America        8         1          1
# 34  United States of America        7         1          1
# 35  United States of America        8         1          1
# 36  United States of America       14         1          1
# 37  United States of America        4         1          1
# 38  United States of America        9         1          1
# 39  United States of America        8         1          1
# 40  United States of America        9         1          1
# 41  United States of America       13         1          1
# 42  United States of America        8         1          1
# 43  United States of America       20         1          1
# 44  United States of America        8         1          1
# 45  United States of America       10         1          1
# 46  United States of America        8         1          1
# 47  United States of America       12         1          1
# 48  United States of America        5         1          1
# 49  United States of America        8         1          1
# 50  United States of America        6         1          1
#
#           featureclass                                           geometry
# 0   Admin-1 scale rank  POLYGON ((-89.59941 48.01027, -89.48888 48.013...
# 1   Admin-1 scale rank  POLYGON ((-111.19419 44.56116, -111.29155 44.7...
# 2   Admin-1 scale rank  POLYGON ((-96.60136 46.35136, -96.53891 46.199...
# 3   Admin-1 scale rank  MULTIPOLYGON (((-155.93665 19.05939, -155.9080...
# 4   Admin-1 scale rank  POLYGON ((-111.04973 44.48816, -111.05024 42.0...
# 5   Admin-1 scale rank  POLYGON ((-116.99807 46.33017, -116.90653 46.1...
# 6   Admin-1 scale rank  POLYGON ((-109.04522 36.99991, -109.04367 31.3...
# 7   Admin-1 scale rank  POLYGON ((-114.35490 34.46467, -114.16597 34.2...
# 8   Admin-1 scale rank  POLYGON ((-102.05017 40.00081, -102.04012 38.4...
# 9   Admin-1 scale rank  POLYGON ((-114.03053 36.99410, -114.02363 36.1...
# 10  Admin-1 scale rank  POLYGON ((-103.00161 33.87995, -103.00161 31.9...
# 11  Admin-1 scale rank  POLYGON ((-117.02825 42.00002, -117.02825 41.9...
# 12  Admin-1 scale rank  POLYGON ((-109.05318 41.00199, -109.04522 36.9...
# 13  Admin-1 scale rank  POLYGON ((-111.06719 44.54160, -111.07141 45.0...
# 14  Admin-1 scale rank  POLYGON ((-89.66292 36.02307, -89.67351 35.940...
# 15  Admin-1 scale rank  POLYGON ((-90.15664 42.10374, -90.21007 41.834...
# 16  Admin-1 scale rank  POLYGON ((-94.60481 39.13986, -94.61538 38.068...
# 17  Admin-1 scale rank  POLYGON ((-94.61750 36.99991, -94.62280 36.999...
# 18  Admin-1 scale rank  POLYGON ((-95.45254 40.21514, -95.32288 40.001...
# 19  Admin-1 scale rank  POLYGON ((-94.62861 36.54059, -94.43017 35.483...
# 20  Admin-1 scale rank  POLYGON ((-96.75427 42.63396, -97.02839 42.717...
# 21  Admin-1 scale rank  POLYGON ((-89.21767 29.29108, -89.40839 29.159...
# 22  Admin-1 scale rank  POLYGON ((-93.57824 31.21613, -93.48984 31.079...
# 23  Admin-1 scale rank  POLYGON ((-72.87617 41.22056, -73.64789 40.953...
# 24  Admin-1 scale rank  POLYGON ((-69.88480 41.92276, -69.96521 41.636...
# 25  Admin-1 scale rank  POLYGON ((-71.50351 45.00780, -71.50509 45.008...
# 26  Admin-1 scale rank  POLYGON ((-71.14790 41.64759, -71.12038 41.494...
# 27  Admin-1 scale rank  POLYGON ((-71.50351 45.00780, -71.62045 44.735...
# 28  Admin-1 scale rank  POLYGON ((-85.05442 31.10870, -85.00519 30.990...
# 29  Admin-1 scale rank  POLYGON ((-80.05654 26.88000, -80.08801 26.205...
# 30  Admin-1 scale rank  POLYGON ((-80.86501 32.03316, -81.33629 31.440...
# 31  Admin-1 scale rank  POLYGON ((-88.16696 34.99967, -88.09552 34.805...
# 32  Admin-1 scale rank  POLYGON ((-78.55411 33.86142, -79.06067 33.493...
# 33  Admin-1 scale rank  POLYGON ((-90.64082 42.50536, -89.62005 42.505...
# 34  Admin-1 scale rank  POLYGON ((-84.80676 41.67774, -84.80993 40.772...
# 35  Admin-1 scale rank  POLYGON ((-81.97254 37.53595, -82.37259 37.238...
# 36  Admin-1 scale rank  POLYGON ((-75.86808 36.55118, -75.72731 35.550...
# 37  Admin-1 scale rank  POLYGON ((-82.21066 38.57948, -82.34083 38.440...
# 38  Admin-1 scale rank  POLYGON ((-81.67938 36.58557, -81.70477 36.460...
# 39  Admin-1 scale rank  MULTIPOLYGON (((-75.37754 38.01538, -75.94003 ...
# 40  Admin-1 scale rank  POLYGON ((-86.48156 45.32318, -86.26460 45.226...
# 41  Admin-1 scale rank  POLYGON ((-77.72280 39.32243, -77.83499 39.134...
# 42  Admin-1 scale rank  POLYGON ((-75.31987 38.95995, -75.07183 38.782...
# 43  Admin-1 scale rank  POLYGON ((-76.91158 38.87845, -77.04124 38.789...
# 44  Admin-1 scale rank  POLYGON ((-75.04839 38.44876, -75.05673 38.404...
# 45  Admin-1 scale rank  POLYGON ((-73.91280 40.96019, -73.95232 40.750...
# 46  Admin-1 scale rank  POLYGON ((-74.67903 41.35549, -74.84044 41.426...
# 47  Admin-1 scale rank  POLYGON ((-74.89175 40.08179, -75.12882 39.949...
# 48  Admin-1 scale rank  POLYGON ((-67.13734 45.13745, -66.96466 44.809...
# 49  Admin-1 scale rank  POLYGON ((-90.39528 46.61168, -90.35559 46.673...
# 50  Admin-1 scale rank  MULTIPOLYGON (((-153.22873 57.96897, -152.5647...
#
# [51 rows x 41 columns]

# %% [markdown]
# 3. Obtener estadísticas descriptivas de las columnas del dataframe

# %%
# tu codigo aqui
serie = data.dtypes
columnas = []
# Buscamos todas las columnas que podamos hacer estadística descriptiva
for elem in serie.index: 
  # Si es int o float lo guardamos
  if serie[elem] == "int64" or serie[elem] == "float64":
    columnas.append(elem)

# Para todas las que sean de int o float obtenemos sus correspondientes estadísticas descriptivas
for col in columnas: 
  print(data[col].describe())
# Out:
# count    51.0
# mean      2.0
# std       0.0
# min       2.0
# 25%       2.0
# 50%       2.0
# 75%       2.0
# max       2.0
# Name: scalerank, dtype: float64
# count      51.000000
# mean     3538.000000
# std        14.866069
# min      3513.000000
# 25%      3525.500000
# 50%      3538.000000
# 75%      3550.500000
# max      3563.000000
# Name: diss_me, dtype: float64
# count    51.000000
# mean      2.627451
# std       2.332044
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       5.000000
# max       8.000000
# Name: adm0_sr, dtype: float64
# count    51.0
# mean      2.0
# std       0.0
# min       2.0
# 25%       2.0
# 50%       2.0
# 75%       2.0
# max       2.0
# Name: admin0_lab, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: name_local, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: note, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: region_cod, dtype: float64
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: big_code, dtype: float64
# count    51.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: provnum_ne, dtype: float64
# count    51.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: gadm_level, dtype: float64
# count    51.000000
# mean      0.588235
# std       2.376354
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      10.000000
# Name: check_me, dtype: float64
# count    51.0
# mean      2.0
# std       0.0
# min       2.0
# 25%       2.0
# 50%       2.0
# 75%       2.0
# max       2.0
# Name: scaleran_1, dtype: float64
# count    51.000000
# mean      1.137255
# std       0.980196
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       1.000000
# max       8.000000
# Name: datarank, dtype: float64
# count    51.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: area_sqkm, dtype: float64
# count    51.000000
# mean    -96.882353
# std      15.123025
# min     -99.000000
# 25%     -99.000000
# 50%     -99.000000
# 75%     -99.000000
# max       9.000000
# Name: sameascity, dtype: float64
# count    51.000000
# mean      0.176471
# std       1.260252
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       9.000000
# Name: labelrank, dtype: float64
# count    51.000000
# mean      8.666667
# std       3.076795
# min       4.000000
# 25%       7.000000
# 50%       8.000000
# 75%      10.000000
# max      20.000000
# Name: name_len, dtype: float64
# count    51.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: mapcolor9, dtype: float64
# count    51.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# Name: mapcolor13, dtype: float64

# %% [markdown]
# 4. ¿Cuántos países están representados en el archivo?

# %%
# tu codigo aqui
# supongo que son estados 
print(len(data['iso_3166_2'].unique()))
# Out:
# ['US-MN' 'US-MT' 'US-ND' 'US-HI' 'US-ID' 'US-WA' 'US-AZ' 'US-CA' 'US-CO'
#  'US-NV' 'US-NM' 'US-OR' 'US-UT' 'US-WY' 'US-AR' 'US-IA' 'US-KS' 'US-MO'
#  'US-NE' 'US-OK' 'US-SD' 'US-LA' 'US-TX' 'US-CT' 'US-MA' 'US-NH' 'US-RI'
#  'US-VT' 'US-AL' 'US-FL' 'US-GA' 'US-MS' 'US-SC' 'US-IL' 'US-IN' 'US-KY'
#  'US-NC' 'US-OH' 'US-TN' 'US-VA' 'US-WI' 'US-WV' 'US-DE' 'US-DC' 'US-MD'
#  'US-NJ' 'US-NY' 'US-PA' 'US-ME' 'US-MI' 'US-AK']
# 51
# 51

# %% [markdown]
# 5.  ¿Cuáles son los nombres de los tres países con mayor superficie?

# %%
# tu codigo aqui
data['area'] = data.area
# Out:
# <ipython-input-35-bc065c551923>:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   data['area'] = data.area

# %%
areas = data['area']
areas = areas.sort_values(ascending = False)
print(areas[:3])
# Out:
# 50    281.055732
# 22     65.647054
# 1      44.590861
# Name: area, dtype: float64

# %% [markdown]
# 6. Crea un mapa coroplético para visualizar la clasificación anterior

# %%
# tu codigo aqui
data.plot(column='area', legend = True)
# Out:
# <Axes: >

# %% [markdown]
# 6. Crea un mapa interactivo para visualizar los estados/provincias con los nombres de las entidades

# %%
# tu codigo aqui
data.explore(tooltip='iso_3166_2')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dc59efee085cc1f13ecfc5e50c24ac5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dc59efee085cc1f13ecfc5e50c24ac5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6dc59efee085cc1f13ecfc5e50c24ac5 = L.map(
#                 &quot;map_6dc59efee085cc1f13ecfc5e50c24ac5&quot;,
#                 {
#                     center: [45.136976788470946, -119.37788530144559],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6dc59efee085cc1f13ecfc5e50c24ac5);
#
#
#
#
#
#             var tile_layer_6e524a1fbbc3f67e9d09f5d623724260 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6dc59efee085cc1f13ecfc5e50c24ac5);
#
#
#             map_6dc59efee085cc1f13ecfc5e50c24ac5.fitBounds(
#                 [[18.916190000000142, -171.79111060289117], [71.35776357694175, -66.96466]],
#                 {}
#             );
#
#
#         function geo_json_81099fe127d65f2e2754210b5d532aba_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_81099fe127d65f2e2754210b5d532aba_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_81099fe127d65f2e2754210b5d532aba_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_81099fe127d65f2e2754210b5d532aba_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_81099fe127d65f2e2754210b5d532aba_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_81099fe127d65f2e2754210b5d532aba.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_81099fe127d65f2e2754210b5d532aba_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_81099fe127d65f2e2754210b5d532aba = L.geoJson(null, {
#                 onEachFeature: geo_json_81099fe127d65f2e2754210b5d532aba_onEachFeature,
#
#                 style: geo_json_81099fe127d65f2e2754210b5d532aba_styler,
#                 pointToLayer: geo_json_81099fe127d65f2e2754210b5d532aba_pointToLayer
#         });
#
#         function geo_json_81099fe127d65f2e2754210b5d532aba_add (data) {
#             geo_json_81099fe127d65f2e2754210b5d532aba
#                 .addData(data)
#                 .addTo(map_6dc59efee085cc1f13ecfc5e50c24ac5);
#         }
#             geo_json_81099fe127d65f2e2754210b5d532aba_add({&quot;bbox&quot;: [-171.79111060289117, 18.916190000000142, -66.96466, 71.35776357694175], &quot;features&quot;: [{&quot;bbox&quot;: [-97.22894344764501, 43.50018748633539, -89.48888455722101, 49.38928538674975], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-89.59940914585667, 48.01027395282483], [-89.48888455722101, 48.01343887860651], [-89.52269548211933, 47.96053538674391], [-89.61369767938538, 47.81925202085796], [-89.72800594761503, 47.641976019880644], [-89.84283098016755, 47.464725857119504], [-89.95765601272012, 47.28690725360326], [-90.13175391311142, 47.29274669045219], [-90.30585181350267, 47.29801768654602], [-90.47994
