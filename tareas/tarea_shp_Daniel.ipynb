# %%
#Estas son las librerias que vas a usar
import geopandas as gpd
import matplotlib.pyplot as plt
from mapclassify import classify
import pandas as pd
import numpy as np
import folium
import geopy

# %% [markdown]
# 1. Crea un mapa para visualizar el archivo:
# https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_admin_1_states_provinces_shp.geojson

# %%
# tu codigo aqui
map = gpd.read_file('https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_admin_1_states_provinces_shp.geojson')
map.plot()
# Out:
# <Axes: >

# %% [markdown]
# 2. Obtener toda la información sobre el dataframe.

# %%
# tu codigo aqui
map.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   scalerank     51 non-null     int64
#  1   adm1_code     51 non-null     object
#  2   diss_me       51 non-null     int64
#  3   adm1_cod_1    51 non-null     object
#  4   iso_3166_2    51 non-null     object
#  5   wikipedia     51 non-null     object
#  6   sr_sov_a3     51 non-null     object
#  7   sr_adm0_a3    51 non-null     object
#  8   iso_a2        51 non-null     object
#  9   adm0_sr       51 non-null     int64
#  10  admin0_lab    51 non-null     int64
#  11  name          51 non-null     object
#  12  name_alt      51 non-null     object
#  13  name_local    0 non-null      float64
#  14  type          51 non-null     object
#  15  type_en       51 non-null     object
#  16  code_local    51 non-null     object
#  17  code_hasc     51 non-null     object
#  18  note          0 non-null      float64
#  19  hasc_maybe    2 non-null      object
#  20  region        50 non-null     object
#  21  region_cod    0 non-null      float64
#  22  region_big    50 non-null     object
#  23  big_code      0 non-null      float64
#  24  provnum_ne    51 non-null     int64
#  25  gadm_level    51 non-null     int64
#  26  check_me      51 non-null     int64
#  27  scaleran_1    51 non-null     int64
#  28  datarank      51 non-null     int64
#  29  abbrev        51 non-null     object
#  30  postal        51 non-null     object
#  31  area_sqkm     51 non-null     int64
#  32  sameascity    51 non-null     int64
#  33  labelrank     51 non-null     int64
#  34  featurec_1    51 non-null     object
#  35  admin         51 non-null     object
#  36  name_len      51 non-null     int64
#  37  mapcolor9     51 non-null     int64
#  38  mapcolor13    51 non-null     int64
#  39  featureclass  51 non-null     object
#  40  geometry      51 non-null     geometry
# dtypes: float64(4), geometry(1), int64(15), object(21)
# memory usage: 16.5+ KB

# %% [markdown]
# 3. Obtener estadísticas descriptivas de las columnas del dataframe

# %%
# tu codigo aqui
map.describe()
# Out:
#        scalerank      diss_me    adm0_sr  admin0_lab  name_local  note
# count       51.0    51.000000  51.000000        51.0         0.0   0.0  \
# mean         2.0  3538.000000   2.627451         2.0         NaN   NaN
# std          0.0    14.866069   2.332044         0.0         NaN   NaN
# min          2.0  3513.000000   1.000000         2.0         NaN   NaN
# 25%          2.0  3525.500000   1.000000         2.0         NaN   NaN
# 50%          2.0  3538.000000   1.000000         2.0         NaN   NaN
# 75%          2.0  3550.500000   5.000000         2.0         NaN   NaN
# max          2.0  3563.000000   8.000000         2.0         NaN   NaN
#
#        region_cod  big_code  provnum_ne  gadm_level   check_me  scaleran_1
# count         0.0       0.0        51.0        51.0  51.000000        51.0  \
# mean          NaN       NaN         0.0         1.0   0.588235         2.0
# std           NaN       NaN         0.0         0.0   2.376354         0.0
# min           NaN       NaN         0.0         1.0   0.000000         2.0
# 25%           NaN       NaN         0.0         1.0   0.000000         2.0
# 50%           NaN       NaN         0.0         1.0   0.000000         2.0
# 75%           NaN       NaN         0.0         1.0   0.000000         2.0
# max           NaN       NaN         0.0         1.0  10.000000         2.0
#
#         datarank  area_sqkm  sameascity  labelrank   name_len  mapcolor9
# count  51.000000       51.0   51.000000  51.000000  51.000000       51.0  \
# mean    1.137255        0.0  -96.882353   0.176471   8.666667        1.0
# std     0.980196        0.0   15.123025   1.260252   3.076795        0.0
# min     1.000000        0.0  -99.000000   0.000000   4.000000        1.0
# 25%     1.000000        0.0  -99.000000   0.000000   7.000000        1.0
# 50%     1.000000        0.0  -99.000000   0.000000   8.000000        1.0
# 75%     1.000000        0.0  -99.000000   0.000000  10.000000        1.0
# max     8.000000        0.0    9.000000   9.000000  20.000000        1.0
#
#        mapcolor13
# count        51.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0

# %% [markdown]
# 4. ¿Cuántos países están representados en el archivo?

# %%
# tu codigo aqui
map.groupby('admin').count()
# Out:
#                           scalerank  adm1_code  diss_me  adm1_cod_1
# admin
# United States of America         51         51       51          51  \
#
#                           iso_3166_2  wikipedia  sr_sov_a3  sr_adm0_a3
# admin
# United States of America          51         51         51          51  \
#
#                           iso_a2  adm0_sr  ...  postal  area_sqkm  sameascity
# admin                                      ...
# United States of America      51       51  ...      51         51          51  \
#
#                           labelrank  featurec_1  name_len  mapcolor9
# admin
# United States of America         51          51        51         51  \
#
#                           mapcolor13  featureclass  geometry
# admin
# United States of America          51            51        51
#
# [1 rows x 40 columns]

# %% [markdown]
# ### 1

# %% [markdown]
# 5.  ¿Cuáles son los nombres de los tres países con mayor superficie?

# %%
areas = map.area
grandes = areas.sort_values(ascending=False)[:3].index
map.iloc[grandes]
# Out:
# /tmp/ipykernel_172/2808187120.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   areas = map.area
#     scalerank adm1_code  diss_me adm1_cod_1 iso_3166_2
# 50          2  USA-3563     3563   USA-3563      US-AK  \
# 22          2  USA-3536     3536   USA-3536      US-TX
# 1           2  USA-3515     3515   USA-3515      US-MT
#
#                                wikipedia sr_sov_a3 sr_adm0_a3 iso_a2  adm0_sr
# 50   http://en.wikipedia.org/wiki/Alaska       US1        USA     US        6  \
# 22    http://en.wikipedia.org/wiki/Texas       US1        USA     US        4
# 1   http://en.wikipedia.org/wiki/Montana       US1        USA     US        1
#
#     ...  area_sqkm sameascity labelrank          featurec_1
# 50  ...          0        -99         0  Admin-1 scale rank  \
# 22  ...          0        -99         0  Admin-1 scale rank
# 1   ...          0        -99         0  Admin-1 scale rank
#
#                        admin name_len mapcolor9 mapcolor13
# 50  United States of America        6         1          1  \
# 22  United States of America        5         1          1
# 1   United States of America        7         1          1
#
#           featureclass                                           geometry
# 50  Admin-1 scale rank  MULTIPOLYGON (((-153.22873 57.96897, -152.5647...
# 22  Admin-1 scale rank  POLYGON ((-93.57824 31.21613, -93.48984 31.079...
# 1   Admin-1 scale rank  POLYGON ((-111.19419 44.56116, -111.29155 44.7...
#
# [3 rows x 41 columns]

# %% [markdown]
# 6. Crea un mapa coroplético para visualizar la clasificación anterior

# %%
map['area'] = map.area
# Out:
# /tmp/ipykernel_172/126645082.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map['area'] = map.area

# %%
fig, ax = plt.subplots(1, figsize=(10,6))
map.plot(column='area', cmap='Blues', linewidth=1, ax=ax, edgecolor='0.9', legend = True)
ax.axis('off')
# Out:
# (-177.03243313303574, -61.72333746985544, 16.29411132115306, 73.97984225578882)

# %% [markdown]
# 6. Crea un mapa interactivo para visualizar los estados/provincias con los nombres de las entidades

# %%
# tu codigo aqui
map.explore()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/formatters.py:344, in BaseFormatter.__call__(self, obj)
#     342     method = get_real_method(obj, self.print_method)
#     343     if method is not None:
# --> 344         return method()
#     345     return None
#     346 else:
#
# File /opt/conda/lib/python3.10/site-packages/folium/folium.py:319, in Map._repr_html_(self, **kwargs)
#     317     self._parent = None
#     318 else:
# --> 319     out = self._parent._repr_html_(**kwargs)
#     320 return out
#
# File /opt/conda/lib/python3.10/site-packages/branca/element.py:343, in Figure._repr_html_(self, **kwargs)
#     341 def _repr_html_(self, **kwargs):
#     342     """Displays the Figure in a Jupyter notebook."""
# --> 343     html = escape(self.render(**kwargs))
#     344     if self.height is None:
#     345         iframe = (
#     346             '<div style="width:{width};">'
#     347             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     353             '</div></div>'
#     354         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File /opt/conda/lib/python3.10/site-packages/branca/element.py:338, in Figure.render(self, **kwargs)
#     336 """Renders the HTML representation of the element."""
#     337 for name, child in self._children.items():
# --> 338     child.render(**kwargs)
#     339 return self._template.render(this=self, kwargs=kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/folium/folium.py:401, in Map.render(self, **kwargs)
#     374 figure.header.add_child(
#     375     Element(
#     376         "<style>html, body {"
#    (...)
#     384     name="css_style",
#     385 )
#     387 figure.header.add_child(
#     388     Element(
#     389         "<style>#map {"
#    (...)
#     398     name="map_style",
#     399 )
# --> 401 super().render(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/folium/elements.py:22, in JSCSSMixin.render(self, **kwargs)
#      19 for name, url in self.default_css:
#      20     figure.header.add_child(CssLink(url), name=name)
# ---> 22 super().render(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/branca/element.py:645, in MacroElement.render(self, **kwargs)
#     641     figure.script.add_child(Element(script(self, kwargs)),
#     642                             name=self.get_name())
#     644 for name, element in self._children.items():
# --> 645     element.render(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/folium/features.py:782, in GeoJson.render(self, **kwargs)
#     780     if self.highlight:
#     781         self.highlight_map = mapper.get_highlight_map(self.highlight_function)
# --> 782 super().render()
#
# File /opt/conda/lib/python3.10/site-packages/branca/element.py:641, in MacroElement.render(self, **kwargs)
#     639 script = self._template.module.__dict__.get('script', None)
#     640 if script is not None:
# --> 641     figure.script.add_child(Element(script(self, kwargs)),
#     642                             name=self.get_name())
#     644 for name, element in self._children.items():
#     645     element.render(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/jinja2/runtime.py:763, in Macro.__call__(self, *args, **kwargs)
#     757 elif len(args) > self._argument_count:
#     758     raise TypeError(
#     759         f"macro {self.name!r} takes not more than"
#     760         f" {len(self.arguments)} argument(s)"
#     761     )
# --> 763 return self._invoke(arguments, autoescape)
#
# File /opt/conda/lib/python3.10/site-packages/jinja2/runtime.py:777, in Macro._invoke(self, arguments, autoescape)
#     774 if self._environment.is_async:
#     775     return self._async_invoke(arguments, autoescape)  # type: ignore
# --> 777 rv = self._func(*arguments)
#     779 if autoescape:
#     780     rv = Markup(rv)
#
# File <template>:238, in macro(l_1_this, l_1_kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/jinja2/filters.py:1688, in do_tojson(eval_ctx, value, indent)
#    1685     kwargs = kwargs.copy()
#    1686     kwargs["indent"] = indent
# -> 1688 return htmlsafe_json_dumps(value, dumps=dumps, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/jinja2/utils.py:658, in htmlsafe_json_dumps(obj, dumps, **kwargs)
#     654 if dumps is None:
#     655     dumps = json.dumps
#     657 return markupsafe.Markup(
# --> 658     dumps(obj, **kwargs)
#     659     .replace("<", "\\u003c")
#     660     .replace(">", "\\u003e")
#     661     .replace("&", "\\u0026")
#     662     .replace("'", "\\u0027")
#     663 )
#
# File /opt/conda/lib/python3.10/json/__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File /opt/conda/lib/python3.10/json/encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File /opt/conda/lib/python3.10/json/encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# TypeError: '<' not supported between instances of 'int' and 'str'
