# %%
#Estas son las librerias que vas a usar
import geopandas as gpd
import matplotlib.pyplot as plt
from mapclassify import classify
import pandas as pdç
import numpy as np
import folium
import geopy

# %% [markdown]
# 1. Crea un mapa para visualizar el archivo:
# https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_admin_1_states_provinces_shp.geojson

# %%
# tu codigo aqui
mapa = gpd.read_file("https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_110m_admin_1_states_provinces_shp.geojson")
mapa.plot()
# Out:
# <Axes: >

# %% [markdown]
# 2. Obtener toda la información sobre el dataframe.

# %%
# tu codigo aqui
mapa.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 41 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   scalerank     51 non-null     int64
#  1   adm1_code     51 non-null     object
#  2   diss_me       51 non-null     int64
#  3   adm1_cod_1    51 non-null     object
#  4   iso_3166_2    51 non-null     object
#  5   wikipedia     51 non-null     object
#  6   sr_sov_a3     51 non-null     object
#  7   sr_adm0_a3    51 non-null     object
#  8   iso_a2        51 non-null     object
#  9   adm0_sr       51 non-null     int64
#  10  admin0_lab    51 non-null     int64
#  11  name          51 non-null     object
#  12  name_alt      51 non-null     object
#  13  name_local    0 non-null      float64
#  14  type          51 non-null     object
#  15  type_en       51 non-null     object
#  16  code_local    51 non-null     object
#  17  code_hasc     51 non-null     object
#  18  note          0 non-null      float64
#  19  hasc_maybe    2 non-null      object
#  20  region        50 non-null     object
#  21  region_cod    0 non-null      float64
#  22  region_big    50 non-null     object
#  23  big_code      0 non-null      float64
#  24  provnum_ne    51 non-null     int64
#  25  gadm_level    51 non-null     int64
#  26  check_me      51 non-null     int64
#  27  scaleran_1    51 non-null     int64
#  28  datarank      51 non-null     int64
#  29  abbrev        51 non-null     object
#  30  postal        51 non-null     object
#  31  area_sqkm     51 non-null     int64
#  32  sameascity    51 non-null     int64
#  33  labelrank     51 non-null     int64
#  34  featurec_1    51 non-null     object
#  35  admin         51 non-null     object
#  36  name_len      51 non-null     int64
#  37  mapcolor9     51 non-null     int64
#  38  mapcolor13    51 non-null     int64
#  39  featureclass  51 non-null     object
#  40  geometry      51 non-null     geometry
# dtypes: float64(4), geometry(1), int64(15), object(21)
# memory usage: 16.5+ KB

# %% [markdown]
# 3. Obtener estadísticas descriptivas de las columnas del dataframe

# %%
# tu codigo aqui
mapa.describe()
# Out:
#        scalerank      diss_me    adm0_sr  admin0_lab  provnum_ne  gadm_level  \
# count       51.0    51.000000  51.000000        51.0        51.0        51.0
# mean         2.0  3538.000000   2.627451         2.0         0.0         1.0
# std          0.0    14.866069   2.332044         0.0         0.0         0.0
# min          2.0  3513.000000   1.000000         2.0         0.0         1.0
# 25%          2.0  3525.500000   1.000000         2.0         0.0         1.0
# 50%          2.0  3538.000000   1.000000         2.0         0.0         1.0
# 75%          2.0  3550.500000   5.000000         2.0         0.0         1.0
# max          2.0  3563.000000   8.000000         2.0         0.0         1.0
#
#         check_me  scaleran_1   datarank  area_sqkm  sameascity  labelrank  \
# count  51.000000        51.0  51.000000       51.0   51.000000  51.000000
# mean    0.588235         2.0   1.137255        0.0  -96.882353   0.176471
# std     2.376354         0.0   0.980196        0.0   15.123025   1.260252
# min     0.000000         2.0   1.000000        0.0  -99.000000   0.000000
# 25%     0.000000         2.0   1.000000        0.0  -99.000000   0.000000
# 50%     0.000000         2.0   1.000000        0.0  -99.000000   0.000000
# 75%     0.000000         2.0   1.000000        0.0  -99.000000   0.000000
# max    10.000000         2.0   8.000000        0.0    9.000000   9.000000
#
#         name_len  mapcolor9  mapcolor13
# count  51.000000       51.0        51.0
# mean    8.666667        1.0         1.0
# std     3.076795        0.0         0.0
# min     4.000000        1.0         1.0
# 25%     7.000000        1.0         1.0
# 50%     8.000000        1.0         1.0
# 75%    10.000000        1.0         1.0
# max    20.000000        1.0         1.0

# %% [markdown]
# 4. ¿Cuántos países están representados en el archivo?

# %%
# tu codigo aqui
# El df solo tiene 1 pais, E.E.U.U,  pero con len podemos saber el número de estados.
len(mapa)
# Out:
# 51

# %% [markdown]
# 5.  ¿Cuáles son los nombres de los tres países con mayor superficie?

# %%
# tu codigo aqui
mapa["area"] = mapa.area
top = mapa.sort_values(by = ['area'], ascending = False).head(3)
top
# Out:
# /tmp/ipykernel_1330/414282129.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   mapa["area"] = mapa.area
#     scalerank adm1_code  diss_me adm1_cod_1 iso_3166_2  \
# 50          2  USA-3563     3563   USA-3563      US-AK
# 22          2  USA-3536     3536   USA-3536      US-TX
# 1           2  USA-3515     3515   USA-3515      US-MT
#
#                                wikipedia sr_sov_a3 sr_adm0_a3 iso_a2  adm0_sr  \
# 50   http://en.wikipedia.org/wiki/Alaska       US1        USA     US        6
# 22    http://en.wikipedia.org/wiki/Texas       US1        USA     US        4
# 1   http://en.wikipedia.org/wiki/Montana       US1        USA     US        1
#
#     ...  sameascity labelrank          featurec_1                     admin  \
# 50  ...         -99         0  Admin-1 scale rank  United States of America
# 22  ...         -99         0  Admin-1 scale rank  United States of America
# 1   ...         -99         0  Admin-1 scale rank  United States of America
#
#    name_len mapcolor9 mapcolor13        featureclass  \
# 50        6         1          1  Admin-1 scale rank
# 22        5         1          1  Admin-1 scale rank
# 1         7         1          1  Admin-1 scale rank
#
#                                              geometry        area
# 50  MULTIPOLYGON (((-153.22873 57.96897, -152.5647...  281.055732
# 22  POLYGON ((-93.57824 31.21613, -93.48984 31.079...   65.647054
# 1   POLYGON ((-111.19419 44.56116, -111.29155 44.7...   44.590861
#
# [3 rows x 42 columns]

# %% [markdown]
# 6. Crea un mapa coroplético para visualizar la clasificación anterior

# %%
# tu codigo aqui
mapa.plot(column="area", legend = True)
top.plot(column="area", legend=True)
# Out:
# <Axes: >

# %% [markdown]
# 6. Crea un mapa interactivo para visualizar los estados/provincias con los nombres de las entidades

# %%
# tu codigo aqui
mapa.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0f83df7f86ab4183c0212f5b60e72fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0f83df7f86ab4183c0212f5b60e72fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0f83df7f86ab4183c0212f5b60e72fc = L.map(
#                 &quot;map_e0f83df7f86ab4183c0212f5b60e72fc&quot;,
#                 {
#                     center: [45.136976788470946, -119.37788530144559],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e0f83df7f86ab4183c0212f5b60e72fc);
#
#
#
#
#
#             var tile_layer_0de0fc2317a755b523a8c2c0d811f3db = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e0f83df7f86ab4183c0212f5b60e72fc);
#
#
#             map_e0f83df7f86ab4183c0212f5b60e72fc.fitBounds(
#                 [[18.916190000000142, -171.79111060289117], [71.35776357694175, -66.96466]],
#                 {}
#             );
#
#
#         function geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad = L.geoJson(null, {
#                 onEachFeature: geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_onEachFeature,
#
#                 style: geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_styler,
#                 pointToLayer: geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_pointToLayer
#         });
#
#         function geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_add (data) {
#             geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad
#                 .addData(data)
#                 .addTo(map_e0f83df7f86ab4183c0212f5b60e72fc);
#         }
#             geo_json_c76c5f1aadf6e3d46a1eb4127e2b61ad_add({&quot;bbox&quot;: [-171.79111060289117, 18.916190000000142, -66.96466, 71.35776357694175], &quot;features&quot;: [{&quot;bbox&quot;: [-97.22894344764501, 43.50018748633539, -89.48888455722101, 49.38928538674975], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-89.59940914585667, 48.01027395282483], [-89.48888455722101, 48.01343887860651], [-89.52269548211933, 47.96053538674391], [-89.61369767938538, 47.81925202085796], [-89.72800594761503, 47.641976019880644], [-89.84283098016755, 47.464725857119504], [-89.95765601272012, 47.28690725360326], [-90.13175391311142, 47.29274669045219], [-90.30585181350267, 47.29801768654602], [-90.47994
